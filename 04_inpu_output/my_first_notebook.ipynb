# %% [markdown]
# # Inputs and outputs

# %%
print("Det här fungerar")
# Out:
# Det här fungerar

# %%
# This is a variable that stores my name
name = "Gustav"

print(name)
# Out:
# Gustav

# %%
print(f"Hello, {name}!")
# Out:
# Hello, Gustav!

# %%
name = "Anna"
age = 17
hobby = "programming"
has_rabbit = True
print(f"This is {name}")
print(f"she is {age} years old")
print(f"Her hobby is {hobby}")
print(f"Does she have a rabbit? {has_rabbit}")
# Out:
# This is Anna
# she is 17 years old
# Her hobby is programming
# Does she have a rabbit? True

# %% [markdown]
# # Inputs

# %%
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Hello, gustva!

# %%
gravity = 9.81
# needs to convert the int to be able to do calculations
mass = int(input("Enter your weight in kg: "))

force = mass * gravity

print(f"your force is {force}N")
# Out:
# your force is 618.0300000000001N

# %% [markdown]
# # Math

# %%
import math

PI = math.pi

radius = 2
perimeter = 2 * PI * radius
area = PI * radius ** 2

print(f"radius: {radius}, perimeter: {perimeter}, area: {area}")
# Out:
# radius: 2, perimeter: 12.566370614359172, area: 12.566370614359172
